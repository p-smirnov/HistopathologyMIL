# %%
import numpy as np
import pandas as pd
import os
import glob
import h5py
import wandb

import string
import random

import torch 
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

import lightning as L
from lightning.pytorch.loggers import WandbLogger
from lightning.pytorch.callbacks import ModelCheckpoint


from torch import optim, utils, Tensor

import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay
import sklearn.linear_model


from itables import show
from src.model.SimpleMILModels import Attention, MaxMIL, AttentionResNet
from src.dataloaders.DataLoaders import RetCCLFeatureLoader, RetCCLFeatureLoaderMem


import zarr
import seaborn as sns

recompute_attn = False

# %%
def sigmoid_array(x):
    return 1 / (1 + np.exp(-x))

# %%
import os
os.environ['HTTP_PROXY']="http://www-int.dkfz-heidelberg.de:80"
os.environ['HTTPS_PROXY']="http://www-int.dkfz-heidelberg.de:80"

# %%
group = "BGUAJ0"

# %%
api = wandb.Api()

# %%
runs = api.runs(path="psmirnov/UKHD_RetCLL_299_CT", filters={"group": group})

# %%
runs
# Out:
# <Runs psmirnov/UKHD_RetCLL_299_CT>

# %% [markdown]
# Load in the features (not too much memory needed)

# %%
path_to_extracted_features = '/home/p163v/histopathology/TCGA/ffpe/299/'

# %%
slide_meta = pd.read_csv("../metadata/tcga_labeled_data.csv")

# %%
slide_meta
# Out:
#       Unnamed: 0.1                                         Unnamed: 0  \
# 0                0  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 1                2  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 2                3  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 3                4  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 4                6  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# ...            ...                                                ...
# 3155         12587  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 3156         12594  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 3157         12607  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 3158         12614  /omics/groups/OE0585/internal/p163v/TCGA_downl...
# 3159         12618  /omics/groups/OE0585/internal/p163v/TCGA_downl...
#
#               CT_Status     TCGA_Case  \
# 0        Chromothripsis  TCGA-DC-4745
# 1     No Chromothripsis  TCGA-02-0003
# 2     No Chromothripsis  TCGA-02-0003
# 3     No Chromothripsis  TCGA-02-0003
# 4        Chromothripsis  TCGA-CH-5767
# ...                 ...           ...
# 3155     Chromothripsis  TCGA-66-2769
# 3156  No Chromothripsis  TCGA-D1-A17S
# 3157  No Chromothripsis  TCGA-BB-4217
# 3158  No Chromothripsis  TCGA-QR-A70E
# 3159  No Chromothripsis  TCGA-KN-8419
#
#                                                       0 project     PatientID  \
# 0     TCGA-DC-4745-01Z-00-DX1.f5aa77b0-aa9b-4f0c-a00...    READ  TCGA-DC-4745
# 1     TCGA-02-0003-01Z-00-DX1.6171b175-0972-4e84-999...     GBM  TCGA-02-0003
# 2     TCGA-02-0003-01Z-00-DX2.c7652d8d-d78f-49ae-825...     GBM  TCGA-02-0003
# 3     TCGA-02-0003-01Z-00-DX3.995C2924-E298-4517-82A...     GBM  TCGA-02-0003
# 4     TCGA-CH-5767-01Z-00-DX1.5a8d8c09-2837-4981-9c4...    PRAD  TCGA-CH-5767
# ...                                                 ...     ...           ...
# 3155  TCGA-66-2769-01Z-00-DX1.101b6493-a7b3-42cf-ae2...    LUSC  TCGA-66-2769
# 3156  TCGA-D1-A17S-01Z-00-DX1.8EBE62E2-B0D1-480D-8A1...    UCEC  TCGA-D1-A17S
# 3157  TCGA-BB-4217-01Z-00-DX1.E351C8DB-F6CB-4327-9FE...    HNSC  TCGA-BB-4217
# 3158  TCGA-QR-A70E-01Z-00-DX1.1BF4CFF5-C43B-4145-B5A...    PCPG  TCGA-QR-A70E
# 3159  TCGA-KN-8419-01Z-00-DX1.15311E57-CCC5-4D15-88D...    KICH  TCGA-KN-8419
#
#                      slide_id  patches  labels
# 0     TCGA-DC-4745-01Z-00-DX1     3779       1
# 1     TCGA-02-0003-01Z-00-DX1    11146       0
# 2     TCGA-02-0003-01Z-00-DX2     8501       0
# 3     TCGA-02-0003-01Z-00-DX3     2998       0
# 4     TCGA-CH-5767-01Z-00-DX1      998       1
# ...                       ...      ...     ...
# 3155  TCGA-66-2769-01Z-00-DX1     1796       1
# 3156  TCGA-D1-A17S-01Z-00-DX1     8390       0
# 3157  TCGA-BB-4217-01Z-00-DX1     6599       0
# 3158  TCGA-QR-A70E-01Z-00-DX1     4592       0
# 3159  TCGA-KN-8419-01Z-00-DX1     7784       0
#
# [3160 rows x 10 columns]

# %%
slide_meta = pd.read_csv("../metadata/tcga_labeled_data.csv")

# 50 random slides


gbm_slides = slide_meta[slide_meta.project=="GBM"].slide_id

test_labels = slide_meta[slide_meta.project=="GBM"].labels

#all_files = [x for x in slide_annots.file if os.path.isfile(path_to_extracted_features + "/" + x)]
#    all_features = {file: h5py.File(path_to_extracted_features + "/" + file, 'r')['feats'][:] for file in all_files}

# %%
file_exists = np.array([os.path.exists(path_to_extracted_features + "/" + file + ".h5") for file in gbm_slides])
gbm_slides = gbm_slides[file_exists]
test_labels = test_labels[file_exists]

# %%
test_labels.mean()
# Out:
# 0.7183908045977011

# %%
test_features = [h5py.File(path_to_extracted_features + "/" + file + ".h5", 'r')['feats'][:] for file in gbm_slides]

# %% [markdown]
# # Loss

# %% [markdown]
# We use the loss as the early stopping criteria

# %%
model_list = list()
attention_list = list()
cv =  lambda x: np.std(x) / np.mean(x)

# %%
test_data = RetCCLFeatureLoaderMem(test_features, np.array(test_labels), patches_per_iter='all')

RetCCLTest = DataLoader(test_data, batch_size=1, num_workers=1)#, sampler=valid_Sampler)

# %%
for ii in range(len(runs)):
    
    arts = runs[ii].logged_artifacts()
    arts_dict = {a.name.removesuffix(':'+a.version).split('-')[0]: a for a in arts}
    checkpoint_folder_name = arts_dict['model'].name.split('-')[1].removesuffix(':'+arts_dict['model'].version)
    args = runs[0].config

    model = Attention(2048, lr=args['lr'], weight_decay=args['weight_decay'], hidden_dim=args['hidden_dim'], attention_dim=args['attention_dim'], class_weights=torch.tensor(float(args['class_weights'])))
    chkpt_file = glob.glob('lightning_logs/'+checkpoint_folder_name+'/checkpoints/best_loss*')[0]
    model = model.load_from_checkpoint(chkpt_file, map_location=torch.device('cpu'))
    model.eval()
    model_list.append(model)
    model_attention = [model.attention_forward(torch.tensor(x).to(model.device)).detach().cpu().numpy() for x,y in iter(RetCCLTest)]

    attention_list.append(model_attention)

# %%
len(attention_list)
# Out:
# 5

# %%
attention_combined = [np.hstack(x) for x in zip(*attention_list)]

# %%
np.mean(attention_combined[0], axis=1).shape
# Out:
# (1, 11146)

# %%
for jj in range(len(np.array(gbm_slides))):
        slidename = gbm_slides.iloc[jj]
        print('Writing Attention Map ' + slidename)
        coords = h5py.File(path_to_extracted_features + "/" + slidename + ".h5", 'r')['coords'][:]
        outarray_root = zarr.open("/home/p163v/histopathology/attention_maps/tcga/"+ group + "/"+ slidename + "_per_tile_attention.zarr", mode='w') 
        outarray_root['coords'] = coords
        outarray_root['attn'] = np.mean(attention_combined[jj], axis=1)[:]
# Out:
# Writing Attention Map TCGA-02-0003-01Z-00-DX1
# Writing Attention Map TCGA-02-0003-01Z-00-DX2
# Writing Attention Map TCGA-02-0003-01Z-00-DX3
# Writing Attention Map TCGA-06-0129-01Z-00-DX1
# Writing Attention Map TCGA-06-0129-01Z-00-DX2
# Writing Attention Map TCGA-06-0129-01Z-00-DX3
# Writing Attention Map TCGA-19-0957-01Z-00-DX1
# Writing Attention Map TCGA-06-0143-01Z-00-DX1
# Writing Attention Map TCGA-06-0143-01Z-00-DX2
# Writing Attention Map TCGA-06-0143-01Z-00-DX3
# Writing Attention Map TCGA-4W-AA9R-01Z-00-DX1
# Writing Attention Map TCGA-06-0138-01Z-00-DX1
# Writing Attention Map TCGA-06-0138-01Z-00-DX2
# Writing Attention Map TCGA-06-0138-01Z-00-DX3
# Writing Attention Map TCGA-06-0138-01Z-00-DX4
# Writing Attention Map TCGA-06-5858-01Z-00-DX1
# Writing Attention Map TCGA-06-0646-01Z-00-DX1
# Writing Attention Map TCGA-06-0646-01Z-00-DX2
# Writing Attention Map TCGA-06-0646-01Z-00-DX3
# Writing Attention Map TCGA-41-3915-01Z-00-DX1
# Writing Attention Map TCGA-19-2624-01Z-00-DX1
# Writing Attention Map TCGA-26-5139-01Z-00-DX1
# Writing Attention Map TCGA-12-0707-01Z-00-DX1
# Writing Attention Map TCGA-12-0707-01Z-00-DX2
# Writing Attention Map TCGA-12-0707-01Z-00-DX3
# Writing Attention Map TCGA-12-0707-01Z-00-DX4
# Writing Attention Map TCGA-12-0707-01Z-00-DX5
# Writing Attention Map TCGA-12-3644-01Z-00-DX1
# Writing Attention Map TCGA-12-3644-01Z-00-DX2
# Writing Attention Map TCGA-06-0211-01Z-00-DX1
# Writing Attention Map TCGA-06-0211-01Z-00-DX2
# Writing Attention Map TCGA-26-5134-01Z-00-DX1
# Writing Attention Map TCGA-14-0867-01Z-00-DX1
# Writing Attention Map TCGA-14-0867-01Z-00-DX2
# Writing Attention Map TCGA-14-0867-01Z-00-DX3
# Writing Attention Map TCGA-27-1830-01Z-00-DX1
# Writing Attention Map TCGA-27-1830-01Z-00-DX2
# Writing Attention Map TCGA-27-1830-01Z-00-DX3
# Writing Attention Map TCGA-19-2623-01Z-00-DX1
# Writing Attention Map TCGA-02-0074-01Z-00-DX1
# Writing Attention Map TCGA-14-1795-01Z-00-DX1
# Writing Attention Map TCGA-14-1795-01Z-00-DX2
# Writing Attention Map TCGA-14-1795-01Z-00-DX3
# Writing Attention Map TCGA-14-1795-01Z-00-DX4
# Writing Attention Map TCGA-14-1795-01Z-00-DX5
# Writing Attention Map TCGA-14-1795-01Z-00-DX6
# Writing Attention Map TCGA-14-1795-01Z-00-DX7
# Writing Attention Map TCGA-12-3649-01Z-00-DX1
# Writing Attention Map TCGA-12-3649-01Z-00-DX2
# Writing Attention Map TCGA-12-3649-01Z-00-DX3
# Writing Attention Map TCGA-06-0154-01Z-00-DX1
# Writing Attention Map TCGA-06-0154-01Z-00-DX2
# Writing Attention Map TCGA-06-0154-01Z-00-DX3
# Writing Attention Map TCGA-06-0154-01Z-00-DX4
# Writing Attention Map TCGA-06-0173-01Z-00-DX1
# Writing Attention Map TCGA-06-0173-01Z-00-DX2
# Writing Attention Map TCGA-06-0173-01Z-00-DX3
# Writing Attention Map TCGA-12-1599-01Z-00-DX1
# Writing Attention Map TCGA-12-1599-01Z-00-DX2
# Writing Attention Map TCGA-12-1599-01Z-00-DX3
# Writing Attention Map TCGA-19-5955-01Z-00-DX1
# Writing Attention Map TCGA-06-0195-01Z-00-DX1
# Writing Attention Map TCGA-06-0195-01Z-00-DX2
# Writing Attention Map TCGA-06-0195-01Z-00-DX3
# Writing Attention Map TCGA-06-0195-01Z-00-DX4
# Writing Attention Map TCGA-06-0195-01Z-00-DX5
# Writing Attention Map TCGA-19-5954-01Z-00-DX1
# Writing Attention Map TCGA-02-0006-01Z-00-DX1
# Writing Attention Map TCGA-02-0006-01Z-00-DX2
# Writing Attention Map TCGA-19-5958-01Z-00-DX1
# Writing Attention Map TCGA-06-5408-01Z-00-DX1
# Writing Attention Map TCGA-12-1602-01Z-00-DX1
# Writing Attention Map TCGA-12-1602-01Z-00-DX2
# Writing Attention Map TCGA-12-1602-01Z-00-DX3
# Writing Attention Map TCGA-12-1602-01Z-00-DX4
# Writing Attention Map TCGA-12-1602-01Z-00-DX5
# Writing Attention Map TCGA-12-1094-01Z-00-DX1
# Writing Attention Map TCGA-12-1094-01Z-00-DX2
# Writing Attention Map TCGA-12-1096-01Z-00-DX1
# Writing Attention Map TCGA-12-1096-01Z-00-DX2
# Writing Attention Map TCGA-12-1096-01Z-00-DX3
# Writing Attention Map TCGA-12-1096-01Z-00-DX4
# Writing Attention Map TCGA-26-5135-01Z-00-DX1
# Writing Attention Map TCGA-27-1831-01Z-00-DX1
# Writing Attention Map TCGA-27-1831-01Z-00-DX2
# Writing Attention Map TCGA-27-1831-01Z-00-DX3
# Writing Attention Map TCGA-27-1831-01Z-00-DX4
# Writing Attention Map TCGA-12-0656-01Z-00-DX1
# Writing Attention Map TCGA-12-0656-01Z-00-DX2
# Writing Attention Map TCGA-12-0656-01Z-00-DX3
# Writing Attention Map TCGA-12-0656-01Z-00-DX4
# Writing Attention Map TCGA-14-1453-01Z-00-DX1
# Writing Attention Map TCGA-14-1453-01Z-00-DX2
# Writing Attention Map TCGA-14-1453-01Z-00-DX3
# Writing Attention Map TCGA-14-1453-01Z-00-DX4
# Writing Attention Map TCGA-06-0197-01Z-00-DX1
# Writing Attention Map TCGA-06-0197-01Z-00-DX2
# Writing Attention Map TCGA-06-0197-01Z-00-DX3
# Writing Attention Map TCGA-06-0221-01Z-00-DX1
# Writing Attention Map TCGA-06-0221-01Z-00-DX2
# Writing Attention Map TCGA-06-0221-01Z-00-DX3
# Writing Attention Map TCGA-06-0221-01Z-00-DX4
# Writing Attention Map TCGA-06-0221-01Z-00-DX5
# Writing Attention Map TCGA-06-0221-01Z-00-DX6
# Writing Attention Map TCGA-14-1402-01Z-00-DX1
# Writing Attention Map TCGA-14-1402-01Z-00-DX2
# Writing Attention Map TCGA-14-1402-01Z-00-DX3
# Writing Attention Map TCGA-02-0071-01Z-00-DX1
# Writing Attention Map TCGA-06-5411-01Z-00-DX1
# Writing Attention Map TCGA-06-1086-01Z-00-DX1
# Writing Attention Map TCGA-06-1086-01Z-00-DX2
# Writing Attention Map TCGA-06-0130-01Z-00-DX1
# Writing Attention Map TCGA-06-0130-01Z-00-DX2
# Writing Attention Map TCGA-12-0619-01Z-00-DX1
# Writing Attention Map TCGA-12-0619-01Z-00-DX2
# Writing Attention Map TCGA-12-0619-01Z-00-DX3
# Writing Attention Map TCGA-06-0686-01Z-00-DX1
# Writing Attention Map TCGA-06-0686-01Z-00-DX2
# Writing Attention Map TCGA-19-2631-01Z-00-DX1
# Writing Attention Map TCGA-02-0033-01Z-00-DX1
# Writing Attention Map TCGA-12-1095-01Z-00-DX1
# Writing Attention Map TCGA-12-1095-01Z-00-DX2
# Writing Attention Map TCGA-12-1095-01Z-00-DX3
# Writing Attention Map TCGA-06-0152-01Z-00-DX1
# Writing Attention Map TCGA-06-0152-01Z-00-DX2
# Writing Attention Map TCGA-06-0152-01Z-00-DX3
# Writing Attention Map TCGA-06-0152-01Z-00-DX4
# Writing Attention Map TCGA-06-0152-01Z-00-DX5
# Writing Attention Map TCGA-06-0152-01Z-00-DX6
# Writing Attention Map TCGA-06-0152-01Z-00-DX7
# Writing Attention Map TCGA-06-0152-01Z-00-DX8
# Writing Attention Map TCGA-06-0152-01Z-00-DX9
# Writing Attention Map TCGA-06-0644-01Z-00-DX1
# Writing Attention Map TCGA-14-0789-01Z-00-DX1
# Writing Attention Map TCGA-14-0789-01Z-00-DX2
# Writing Attention Map TCGA-14-0789-01Z-00-DX3
# Writing Attention Map TCGA-14-0789-01Z-00-DX4
# Writing Attention Map TCGA-14-0789-01Z-00-DX5
# Writing Attention Map TCGA-14-0789-01Z-00-DX6
# Writing Attention Map TCGA-14-0789-01Z-00-DX7
# Writing Attention Map TCGA-06-5418-01Z-00-DX1
# Writing Attention Map TCGA-14-1459-01Z-00-DX1
# Writing Attention Map TCGA-14-1459-01Z-00-DX2
# Writing Attention Map TCGA-14-1459-01Z-00-DX3
# Writing Attention Map TCGA-14-1459-01Z-00-DX4
# Writing Attention Map TCGA-14-1459-01Z-00-DX5
# Writing Attention Map TCGA-06-0208-01Z-00-DX1
# Writing Attention Map TCGA-06-0208-01Z-00-DX2
# Writing Attention Map TCGA-06-0208-01Z-00-DX3
# Writing Attention Map TCGA-06-0208-01Z-00-DX4
# Writing Attention Map TCGA-06-0208-01Z-00-DX5
# Writing Attention Map TCGA-06-0208-01Z-00-DX6
# Writing Attention Map TCGA-06-0187-01Z-00-DX1
# Writing Attention Map TCGA-06-0187-01Z-00-DX2
# Writing Attention Map TCGA-06-0187-01Z-00-DX3
# Writing Attention Map TCGA-06-0187-01Z-00-DX4
# Writing Attention Map TCGA-19-5959-01Z-00-DX1
# Writing Attention Map TCGA-14-1401-01Z-00-DX1
# Writing Attention Map TCGA-14-1401-01Z-00-DX2
# Writing Attention Map TCGA-14-1401-01Z-00-DX3
# Writing Attention Map TCGA-19-1386-01Z-00-DX1
# Writing Attention Map TCGA-02-0009-01Z-00-DX1
# Writing Attention Map TCGA-02-0009-01Z-00-DX2
# Writing Attention Map TCGA-02-0009-01Z-00-DX3
# Writing Attention Map TCGA-06-0237-01Z-00-DX1
# Writing Attention Map TCGA-06-0237-01Z-00-DX2
# Writing Attention Map TCGA-12-1099-01Z-00-DX1
# Writing Attention Map TCGA-12-1099-01Z-00-DX2
# Writing Attention Map TCGA-12-1099-01Z-00-DX3
# Writing Attention Map TCGA-27-1835-01Z-00-DX1
# Writing Attention Map TCGA-27-1835-01Z-00-DX2
# Writing Attention Map TCGA-26-1438-01Z-00-DX1
# Writing Attention Map TCGA-12-1089-01Z-00-DX1
# Writing Attention Map TCGA-12-1089-01Z-00-DX2
# Writing Attention Map TCGA-12-1089-01Z-00-DX3
# Writing Attention Map TCGA-28-1757-01Z-00-DX1
# Writing Attention Map TCGA-02-0075-01Z-00-DX1
# Writing Attention Map TCGA-06-5856-01Z-00-DX1
# Writing Attention Map TCGA-06-0126-01Z-00-DX1
# Writing Attention Map TCGA-06-0126-01Z-00-DX2
# Writing Attention Map TCGA-08-0389-01Z-00-DX1
# Writing Attention Map TCGA-06-5413-01Z-00-DX1
# Writing Attention Map TCGA-12-0654-01Z-00-DX1
# Writing Attention Map TCGA-12-0654-01Z-00-DX2
# Writing Attention Map TCGA-12-0654-01Z-00-DX3
# Writing Attention Map TCGA-12-0654-01Z-00-DX4
# Writing Attention Map TCGA-41-2573-01Z-00-DX1
# Writing Attention Map TCGA-06-0881-01Z-00-DX1
# Writing Attention Map TCGA-06-0881-01Z-00-DX2
# Writing Attention Map TCGA-12-0780-01Z-00-DX1
# Writing Attention Map TCGA-12-0780-01Z-00-DX2
# Writing Attention Map TCGA-12-0780-01Z-00-DX3
# Writing Attention Map TCGA-06-0127-01Z-00-DX1
# Writing Attention Map TCGA-06-0127-01Z-00-DX2
# Writing Attention Map TCGA-06-0127-01Z-00-DX3
# Writing Attention Map TCGA-27-2521-01Z-00-DX1
# Writing Attention Map TCGA-06-0648-01Z-00-DX1
# Writing Attention Map TCGA-06-0648-01Z-00-DX2
# Writing Attention Map TCGA-08-0349-01Z-00-DX1
# Writing Attention Map TCGA-12-1090-01Z-00-DX1
# Writing Attention Map TCGA-12-1090-01Z-00-DX2
# Writing Attention Map TCGA-12-0703-01Z-00-DX1
# Writing Attention Map TCGA-12-0703-01Z-00-DX2
# Writing Attention Map TCGA-12-0703-01Z-00-DX3
# Writing Attention Map TCGA-19-5950-01Z-00-DX1
# Writing Attention Map TCGA-12-0616-01Z-00-DX1
# Writing Attention Map TCGA-12-0616-01Z-00-DX2
# Writing Attention Map TCGA-12-0616-01Z-00-DX3
# Writing Attention Map TCGA-12-0616-01Z-00-DX4
# Writing Attention Map TCGA-12-0616-01Z-00-DX5
# Writing Attention Map TCGA-12-0616-01Z-00-DX6
# Writing Attention Map TCGA-12-1098-01Z-00-DX1
# Writing Attention Map TCGA-12-1098-01Z-00-DX2
# Writing Attention Map TCGA-12-0670-01Z-00-DX1
# Writing Attention Map TCGA-12-0670-01Z-00-DX2
# Writing Attention Map TCGA-12-0670-01Z-00-DX3
# Writing Attention Map TCGA-12-0670-01Z-00-DX4
# Writing Attention Map TCGA-19-0964-01Z-00-DX1
# Writing Attention Map TCGA-02-0048-01Z-00-DX1
# Writing Attention Map TCGA-28-1749-01Z-00-DX1
# Writing Attention Map TCGA-12-1091-01Z-00-DX1
# Writing Attention Map TCGA-12-1091-01Z-00-DX2
# Writing Attention Map TCGA-12-1091-01Z-00-DX3
# Writing Attention Map TCGA-19-5960-01Z-00-DX1
# Writing Attention Map TCGA-06-5410-01Z-00-DX1
# Writing Attention Map TCGA-06-1087-01Z-00-DX1
# Writing Attention Map TCGA-06-1087-01Z-00-DX2
# Writing Attention Map TCGA-06-1802-01Z-00-DX1
# Writing Attention Map TCGA-06-1802-01Z-00-DX2
# Writing Attention Map TCGA-41-2572-01Z-00-DX1
# Writing Attention Map TCGA-19-2625-01Z-00-DX1
# Writing Attention Map TCGA-27-1832-01Z-00-DX1
# Writing Attention Map TCGA-27-1832-01Z-00-DX2
# Writing Attention Map TCGA-27-1832-01Z-00-DX3
# Writing Attention Map TCGA-27-1832-01Z-00-DX4
# Writing Attention Map TCGA-06-0201-01Z-00-DX1
# Writing Attention Map TCGA-06-0201-01Z-00-DX2
# Writing Attention Map TCGA-02-0038-01Z-00-DX1
# Writing Attention Map TCGA-12-3651-01Z-00-DX1
# Writing Attention Map TCGA-12-3651-01Z-00-DX2
# Writing Attention Map TCGA-12-3651-01Z-00-DX3
# Writing Attention Map TCGA-12-3651-01Z-00-DX4
# Writing Attention Map TCGA-02-0054-01Z-00-DX1
# Writing Attention Map TCGA-14-1794-01Z-00-DX1
# Writing Attention Map TCGA-14-1794-01Z-00-DX2
