# %%
import numpy as np
import sklearn
import pandas as pd
import h5py

import matplotlib.pyplot as plt

from skimage.transform import resize, pyramid_gaussian
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold

import zarr
import torch

import os
import sys
import re

import openslide

from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay

# %%
slide_meta = pd.read_csv("../metadata/labels_with_new_batch.csv")
ct_scoring = pd.read_csv("../metadata/CT_3_Class_Draft.csv")



ct_scoring["txt_idat"] = ct_scoring["idat"].astype("str")
ct_scoring.index = ct_scoring.txt_idat
slide_meta.index = slide_meta.idat
ct_scoring = ct_scoring.drop("txt_idat", axis=1)
slide_meta = slide_meta.drop("idat", axis=1)
slide_annots = slide_meta.join(ct_scoring, lsuffix="l")


myx = [x in ["Chromothripsis", "No Chromothripsis"] for x in slide_annots.CT_class]

slide_annots = slide_annots.loc[myx]
slide_names = slide_annots.uuid

# slide_names
slide_annots.CT_class
# Out:
# idat
# 10003886253_R02C02       Chromothripsis
# 10003886253_R03C01    No Chromothripsis
# 10003886256_R03C02    No Chromothripsis
# 10003886258_R02C01    No Chromothripsis
# 10003886259_R02C01    No Chromothripsis
#                             ...
# 9969477124_R05C02     No Chromothripsis
# 9980102013_R06C01     No Chromothripsis
# 9980102032_R03C01     No Chromothripsis
# 9980102032_R04C01     No Chromothripsis
# 9980102032_R05C01     No Chromothripsis
# Name: CT_class, Length: 2215, dtype: object

# %%
slide_annots.idat.unique()
# Out:
# array(['10003886253_R02C02', '10003886253_R03C01', '10003886256_R03C02',
#        ..., '9980102032_R03C01', '9980102032_R04C01', '9980102032_R05C01'],
#       dtype=object)

# %%
slide_meta
# Out:
#                                                      uuid  tumor_id  \
# idat
# 204920830120_R01C01  5E876B19-B3C5-42F0-9034-E171C9185A61    234138
# 204920830120_R01C01  FB077233-EDC3-4A52-BD6D-F2F330D7FA62    234138
# 204920830120_R01C01  23A493E4-3A63-410B-9659-3AFDF2C366EE    234138
# 207011010162_R07C01  7EC4A50F-B422-413F-983E-2418103F347F    326008
# 205566000169_R07C01  69DD0320-2930-49DD-9F3A-AAA43519D52A    258410
# ...                                                   ...       ...
# 204339010057_R06C01  872427CC-F757-4CEA-A33F-17B43C872535    173738
# 206947700046_R07C01  AAB165F9-6A45-4545-BCA3-67A0BE33AB26    317894
# 9741950087_R03C02    CADDF04F-C9A1-4A84-A840-1AA1053A982D     67754
# 205059630019_R05C01  24CAA1E6-EA6E-4EB5-81FB-39C2740795ED    254654
# 200091640007_R03C02  354A334F-C664-4414-AD5F-8D42088A7CA3     83270
#
#                                             txt_LOKALISATION  \
# idat
# 204920830120_R01C01  supratentoriell, temporo-frontal rechts
# 204920830120_R01C01  supratentoriell, temporo-frontal rechts
# 204920830120_R01C01  supratentoriell, temporo-frontal rechts
# 207011010162_R07C01  supratentoriell, temporo-insulär rechts
# 205566000169_R07C01                                      NaN
# ...                                                      ...
# 204339010057_R06C01          supratentoriell, Thalamus links
# 206947700046_R07C01                                      NaN
# 9741950087_R03C02             supratentoriell, frontal links
# 205059630019_R05C01                            intrazerebral
# 200091640007_R03C02     infratentoriell, Hirnstamm/Kleinhirn
#
#                      num_ALTERSANGABE  patient_id  \
# idat
# 204920830120_R01C01              34.0      111977
# 204920830120_R01C01              34.0      111977
# 204920830120_R01C01              34.0      111977
# 207011010162_R07C01              37.0      156108
# 205566000169_R07C01               NaN      123570
# ...                               ...         ...
# 204339010057_R06C01              44.0       83651
# 206947700046_R07C01               NaN      151989
# 9741950087_R03C02                31.0        2105
# 205059630019_R05C01              86.0      121779
# 200091640007_R03C02               3.0       37007
#
#                                                 max_super_family_class  \
# idat
# 204920830120_R01C01                         Adult-type diffuse gliomas
# 204920830120_R01C01                         Adult-type diffuse gliomas
# 204920830120_R01C01                         Adult-type diffuse gliomas
# 207011010162_R07C01                         Adult-type diffuse gliomas
# 205566000169_R07C01  diffuse glioma, MAPK altered, cell-cycle activ...
# ...                                                                ...
# 204339010057_R06C01         Paediatric-type diffuse high-grade gliomas
# 206947700046_R07C01                                  Ependymal tumours
# 9741950087_R03C02                           Adult-type diffuse gliomas
# 205059630019_R05C01                         Adult-type diffuse gliomas
# 200091640007_R03C02                                    Control tissues
#
#                                                       max_family_class  \
# idat
# 204920830120_R01C01                         diffuse glioma, IDH mutant
# 204920830120_R01C01                         diffuse glioma, IDH mutant
# 204920830120_R01C01                         diffuse glioma, IDH mutant
# 207011010162_R07C01                         diffuse glioma, IDH mutant
# 205566000169_R07C01               pleomorphic xanthoastrocytoma(-like)
# ...                                                                ...
# 204339010057_R06C01  Diffuse pediatric-type high-grade glioma, H3-w...
# 206947700046_R07C01                           myxopapillary ependymoma
# 9741950087_R03C02                           diffuse glioma, IDH mutant
# 205059630019_R05C01                         Glioblastoma, IDH-wildtype
# 200091640007_R03C02   control tissue, reactive tumour microenvironment
#
#                                                              max_class  \
# idat
# 204920830120_R01C01  diffuse glioma, IDH-mutant and 1p19q retained ...
# 204920830120_R01C01  diffuse glioma, IDH-mutant and 1p19q retained ...
# 204920830120_R01C01  diffuse glioma, IDH-mutant and 1p19q retained ...
# 207011010162_R07C01  diffuse glioma, IDH-mutant and 1p19q retained ...
# 205566000169_R07C01               pleomorphic xanthoastrocytoma(-like)
# ...                                                                ...
# 204339010057_R06C01  Diffuse paediatric-type high grade glioma, RTK...
# 206947700046_R07C01                           myxopapillary ependymoma
# 9741950087_R03C02    diffuse glioma, IDH-mutant and 1p19q retained ...
# 205059630019_R05C01              glioblastoma, IDH-wildtype, RTK1 type
# 200091640007_R03C02   control tissue, reactive tumour microenvironment
#
#                                                           max_subclass  \
# idat
# 204920830120_R01C01                Astrocytoma, IDH-mutant; high grade
# 204920830120_R01C01                Astrocytoma, IDH-mutant; high grade
# 204920830120_R01C01                Astrocytoma, IDH-mutant; high grade
# 207011010162_R07C01               Astrocytoma, IDH-mutant; lower grade
# 205566000169_R07C01                      Pleomorphic xanthoastrocytoma
# ...                                                                ...
# 204339010057_R06C01  Diffuse paediatric-type high grade glioma, RTK...
# 206947700046_R07C01                           Myxopapillary ependymoma
# 9741950087_R03C02                 Astrocytoma, IDH-mutant; lower grade
# 205059630019_R05C01           Glioblastoma, IDH-wildtype, RTK1 subtype
# 200091640007_R03C02   Control tissue, reactive tumour microenvironment
#
#                                              relevant Histo prediction  \
# idat
# 204920830120_R01C01                Astrocytoma, IDH-mutant; high grade
# 204920830120_R01C01                Astrocytoma, IDH-mutant; high grade
# 204920830120_R01C01                Astrocytoma, IDH-mutant; high grade
# 207011010162_R07C01               Astrocytoma, IDH-mutant; lower grade
# 205566000169_R07C01                      Pleomorphic xanthoastrocytoma
# ...                                                                ...
# 204339010057_R06C01  Diffuse paediatric-type high grade glioma, RTK...
# 206947700046_R07C01                           Myxopapillary ependymoma
# 9741950087_R03C02                 Astrocytoma, IDH-mutant; lower grade
# 205059630019_R05C01           Glioblastoma, IDH-wildtype, RTK1 subtype
# 200091640007_R03C02   Control tissue, reactive tumour microenvironment
#
#                                        possible further consolidation  \
# idat
# 204920830120_R01C01                           Astrocytoma, IDH-mutant
# 204920830120_R01C01                           Astrocytoma, IDH-mutant
# 204920830120_R01C01                           Astrocytoma, IDH-mutant
# 207011010162_R07C01                           Astrocytoma, IDH-mutant
# 205566000169_R07C01                     Pleomorphic xanthoastrocytoma
# ...                                                               ...
# 204339010057_R06C01         Diffuse paediatric-type high grade glioma
# 206947700046_R07C01                          Myxopapillary ependymoma
# 9741950087_R03C02                             Astrocytoma, IDH-mutant
# 205059630019_R05C01                        glioblastoma, IDH-wildtype
# 200091640007_R03C02  Control tissue, reactive tumour microenvironment
#
#                                                     classifciation_v11  \
# idat
# 204920830120_R01C01  methylation class IDH glioma, subclass high gr...
# 204920830120_R01C01  methylation class IDH glioma, subclass high gr...
# 204920830120_R01C01  methylation class IDH glioma, subclass high gr...
# 207011010162_R07C01  methylation class IDH glioma, subclass astrocy...
# 205566000169_R07C01  methylation class (anaplastic) pleomorphic xan...
# ...                                                                ...
# 204339010057_R06C01  methylation class CNS neuroblastoma with FOXR2...
# 206947700046_R07C01                                                NaN
# 9741950087_R03C02    methylation class IDH glioma, subclass astrocy...
# 205059630019_R05C01  methylation class glioblastoma, IDH wildtype, ...
# 200091640007_R03C02   methylation class control tissue, reactive brain
#
#                      max_cal_v11                         family  \
# idat
# 204920830120_R01C01     0.912418                    astrocytoma
# 204920830120_R01C01     0.912418                    astrocytoma
# 204920830120_R01C01     0.912418                    astrocytoma
# 207011010162_R07C01     0.934602                    astrocytoma
# 205566000169_R07C01     0.973061  pleomorphic xanthoastrocytoma
# ...                          ...                            ...
# 204339010057_R06C01     0.092167                  neuroblastoma
# 206947700046_R07C01          NaN                            NaN
# 9741950087_R03C02       0.997145                    astrocytoma
# 205059630019_R05C01     0.562538                   glioblastoma
# 200091640007_R03C02     0.964760                        control
#
#                                                              file_path  \
# idat
# 204920830120_R01C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 204920830120_R01C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 204920830120_R01C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 207011010162_R07C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 205566000169_R07C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# ...                                                                ...
# 204339010057_R06C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 206947700046_R07C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 9741950087_R03C02    /omics/odcf/analysis/OE0606_projects/pancancer...
# 205059630019_R05C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 200091640007_R03C02                                                NaN
#
#                                                     slide
# idat
# 204920830120_R01C01  5E876B19-B3C5-42F0-9034-E171C9185A61
# 204920830120_R01C01  FB077233-EDC3-4A52-BD6D-F2F330D7FA62
# 204920830120_R01C01  23A493E4-3A63-410B-9659-3AFDF2C366EE
# 207011010162_R07C01  7EC4A50F-B422-413F-983E-2418103F347F
# 205566000169_R07C01  69DD0320-2930-49DD-9F3A-AAA43519D52A
# ...                                                   ...
# 204339010057_R06C01  872427CC-F757-4CEA-A33F-17B43C872535
# 206947700046_R07C01  AAB165F9-6A45-4545-BCA3-67A0BE33AB26
# 9741950087_R03C02    CADDF04F-C9A1-4A84-A840-1AA1053A982D
# 205059630019_R05C01  24CAA1E6-EA6E-4EB5-81FB-39C2740795ED
# 200091640007_R03C02  354A334F-C664-4414-AD5F-8D42088A7CA3
#
# [6283 rows x 16 columns]

# %%
path_to_extracted_features = '/omics/odcf/analysis/OE0606_projects/pancancer_histopathology/analysis/shared_playground/CNS_classification/embeddings/UNI_256_1024_UKHD_FULL_dataset/pt_files/'


patch_num = []
for x in slide_annots.uuid:
    fl = path_to_extracted_features+x+".pt"
    if(os.path.exists(fl)):
        patch_num.append(torch.load(fl).shape[0])
    else:
        patch_num.append(0)

# %%
slide_annots['patches'] = patch_num

# %%
slide_annots
# Out:
#                                                     uuid  tumor_id  \
# idat
# 10003886253_R02C02  1EE2D6AD-2F2A-4457-BA86-4CC8D137249D     73896
# 10003886253_R03C01  9625ECC7-5AA1-4ADF-B99E-B2F959A2317E     73878
# 10003886256_R03C02  A0517565-0BA3-43F8-A54C-33F403262927     73948
# 10003886258_R02C01  BCEBE5E3-E482-4E27-82FD-A2FFF12F5C84     74034
# 10003886259_R02C01  88FB4DE0-39AE-4FD6-ACFA-68C35A57669F     74022
# ...                                                  ...       ...
# 9969477124_R05C02   24D39BD4-471B-43E7-A23D-1647F9DD9F54     67402
# 9980102013_R06C01   95C1EFE3-112A-48EF-A15C-F7A39AC13247     71960
# 9980102032_R03C01   4C83D422-9DC5-4E3A-A120-6E2DEB47D553     71988
# 9980102032_R04C01   6936A1E9-D6D8-4A44-9CA7-989485943185     71990
# 9980102032_R05C01   8D4B4BCB-02CF-47A2-8003-071C9D006AB4     71992
#
#                                          txt_LOKALISATION  num_ALTERSANGABE  \
# idat
# 10003886253_R02C02                infratentoriell, sakral              30.0
# 10003886253_R03C01         spinal, TH 11/12 extramedullär              71.0
# 10003886256_R03C02                        infratentoriell              34.0
# 10003886258_R02C01  infratentoriell, hintere Schädelgrube              14.0
# 10003886259_R02C01        supratentoriell, frontal rechts              11.0
# ...                                                   ...               ...
# 9969477124_R05C02                                     NaN              21.0
# 9980102013_R06C01                supratentoriell, frontal               9.0
# 9980102032_R03C01       infratentoriell, cerebellär links              27.0
# 9980102032_R04C01               supratentoriell, Thalamus              10.0
# 9980102032_R05C01                        intraventrikulär              39.0
#
#                     patient_id  \
# idat
# 10003886253_R02C02        4981
# 10003886253_R03C01        5395
# 10003886256_R03C02        5460
# 10003886258_R02C01        5457
# 10003886259_R02C01        5459
# ...                        ...
# 9969477124_R05C02         2039
# 9980102013_R06C01         4583
# 9980102032_R03C01         4799
# 9980102032_R04C01         4798
# 9980102032_R05C01         4750
#
#                                                max_super_family_class  \
# idat
# 10003886253_R02C02                                  Ependymal tumours
# 10003886253_R03C01  Mesenchymal, non-meningothelial tumours involv...
# 10003886256_R03C02                                    Control tissues
# 10003886258_R02C01                                    Medulloblastoma
# 10003886259_R02C01  Low-grade glial/glioneuronal/neuroepithelial t...
# ...                                                               ...
# 9969477124_R05C02                                          meningioma
# 9980102013_R06C01          Paediatric-type diffuse high-grade gliomas
# 9980102032_R03C01                                     Medulloblastoma
# 9980102032_R04C01                                     Control tissues
# 9980102032_R05C01                       Inflammatory microenvironment
#
#                                                      max_family_class  \
# idat
# 10003886253_R02C02                           myxopapillary ependymoma
# 10003886253_R03C01           Fibroblastic and myofibroblastic tumours
# 10003886256_R03C02   control tissue, reactive tumour microenvironment
# 10003886258_R02C01                     medulloblastoma, WNT activated
# 10003886259_R02C01                      low-grade glioneuronal tumour
# ...                                                               ...
# 9969477124_R05C02                                          meningioma
# 9980102013_R06C01   Diffuse pediatric-type high-grade glioma, H3-w...
# 9980102032_R03C01                      medulloblastoma, SHH-activated
# 9980102032_R04C01    control tissue, reactive tumour microenvironment
# 9980102032_R05C01                       Inflammatory microenvironment
#
#                                                             max_class  \
# idat
# 10003886253_R02C02                           myxopapillary ependymoma
# 10003886253_R03C01      solitary fibrous tumour / haemangiopericytoma
# 10003886256_R03C02   control tissue, reactive tumour microenvironment
# 10003886258_R02C01                     medulloblastoma, WNT activated
# 10003886259_R02C01            dysembryoplastic neuroepithelial tumour
# ...                                                               ...
# 9969477124_R05C02                                  meningioma, benign
# 9980102013_R06C01   Diffuse paediatric-type high grade glioma, RTK...
# 9980102032_R03C01           medulloblastoma, SHH-activated, subtype 4
# 9980102032_R04C01    control tissue, reactive tumour microenvironment
# 9980102032_R05C01                       Inflammatory microenvironment
#
#                                                          max_subclass  \
# idat
# 10003886253_R02C02                           Myxopapillary ependymoma
# 10003886253_R03C01      Solitary fibrous tumour / haemangiopericytoma
# 10003886256_R03C02   Control tissue, reactive tumour microenvironment
# 10003886258_R02C01                     Medulloblastoma, WNT activated
# 10003886259_R02C01            Dysembryoplastic neuroepithelial tumour
# ...                                                               ...
# 9969477124_R05C02                       Meningioma, subclass benign 1
# 9980102013_R06C01   Diffuse paediatric-type high grade glioma, RTK...
# 9980102032_R03C01           Medulloblastoma, SHH-activated, subtype 4
# 9980102032_R04C01    Control tissue, reactive tumour microenvironment
# 9980102032_R05C01                       Inflammatory microenvironment
#
#                                             relevant Histo prediction  \
# idat
# 10003886253_R02C02                           Myxopapillary ependymoma
# 10003886253_R03C01      Solitary fibrous tumour / haemangiopericytoma
# 10003886256_R03C02   Control tissue, reactive tumour microenvironment
# 10003886258_R02C01                     Medulloblastoma, WNT activated
# 10003886259_R02C01            Dysembryoplastic neuroepithelial tumour
# ...                                                               ...
# 9969477124_R05C02                                  meningioma, benign
# 9980102013_R06C01   Diffuse paediatric-type high grade glioma, RTK...
# 9980102032_R03C01                      medulloblastoma, SHH-activated
# 9980102032_R04C01    Control tissue, reactive tumour microenvironment
# 9980102032_R05C01                       Inflammatory microenvironment
#
#                                       possible further consolidation  \
# idat
# 10003886253_R02C02                          Myxopapillary ependymoma
# 10003886253_R03C01     Solitary fibrous tumour / haemangiopericytoma
# 10003886256_R03C02  Control tissue, reactive tumour microenvironment
# 10003886258_R02C01                    Medulloblastoma, WNT activated
# 10003886259_R02C01           Dysembryoplastic neuroepithelial tumour
# ...                                                              ...
# 9969477124_R05C02                                 meningioma, benign
# 9980102013_R06C01          Diffuse paediatric-type high grade glioma
# 9980102032_R03C01                     medulloblastoma, SHH-activated
# 9980102032_R04C01   Control tissue, reactive tumour microenvironment
# 9980102032_R05C01                      Inflammatory microenvironment
#
#                                                    classifciation_v11  \
# idat
# 10003886253_R02C02        methylation class ependymoma, myxopapillary
# 10003886253_R03C01  methylation class solitary fibrous tumor / hem...
# 10003886256_R03C02  methylation class low grade glioma, subclass p...
# 10003886258_R02C01             methylation class medulloblastoma, WNT
# 10003886259_R02C01  methylation class low grade glioma, dysembryop...
# ...                                                               ...
# 9969477124_R05C02                        methylation class meningioma
# 9980102013_R06C01   methylation class low grade glioma, subclass h...
# 9980102032_R03C01   methylation class medulloblastoma, subclass SH...
# 9980102032_R04C01    methylation class control tissue, reactive brain
# 9980102032_R05C01     methylation class control tissue, inflammatory
#
#                     max_cal_v11                   family  \
# idat
# 10003886253_R02C02     0.996477               ependymoma
# 10003886253_R03C01     0.999968       hemangiopericytoma
# 10003886256_R03C02     0.149055  PA and other MAPK LGGNT
# 10003886258_R02C01     0.999083      medulloblastoma_WNT
# 10003886259_R02C01     0.999950  PA and other MAPK LGGNT
# ...                         ...                      ...
# 9969477124_R05C02      0.999110               meningioma
# 9980102013_R06C01      0.427709  PA and other MAPK LGGNT
# 9980102032_R03C01      0.999697      medulloblastoma_SHH
# 9980102032_R04C01      0.934114                  control
# 9980102032_R05C01      0.987098                  control
#
#                                                             file_path  \
# idat
# 10003886253_R02C02  /omics/odcf/analysis/OE0606_projects/pancancer...
# 10003886253_R03C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 10003886256_R03C02  /omics/odcf/analysis/OE0606_projects/pancancer...
# 10003886258_R02C01  /omics/odcf/analysis/OE0606_projects/pancancer...
# 10003886259_R02C01                                                NaN
# ...                                                               ...
# 9969477124_R05C02   /omics/odcf/analysis/OE0606_projects/pancancer...
# 9980102013_R06C01   /omics/odcf/analysis/OE0606_projects/pancancer...
# 9980102032_R03C01   /omics/odcf/analysis/OE0606_projects/pancancer...
# 9980102032_R04C01   /omics/odcf/analysis/OE0606_projects/pancancer...
# 9980102032_R05C01   /omics/odcf/analysis/OE0606_projects/pancancer...
#
#                                                    slide  Unnamed: 0  \
# idat
# 10003886253_R02C02  1EE2D6AD-2F2A-4457-BA86-4CC8D137249D        41.0
# 10003886253_R03C01  9625ECC7-5AA1-4ADF-B99E-B2F959A2317E        42.0
# 10003886256_R03C02  A0517565-0BA3-43F8-A54C-33F403262927        55.0
# 10003886258_R02C01  BCEBE5E3-E482-4E27-82FD-A2FFF12F5C84        64.0
# 10003886259_R02C01  88FB4DE0-39AE-4FD6-ACFA-68C35A57669F        76.0
# ...                                                  ...         ...
# 9969477124_R05C02   24D39BD4-471B-43E7-A23D-1647F9DD9F54    124466.0
# 9980102013_R06C01   95C1EFE3-112A-48EF-A15C-F7A39AC13247    124579.0
# 9980102032_R03C01   4C83D422-9DC5-4E3A-A120-6E2DEB47D553    124585.0
# 9980102032_R04C01   6936A1E9-D6D8-4A44-9CA7-989485943185    124587.0
# 9980102032_R05C01   8D4B4BCB-02CF-47A2-8003-071C9D006AB4    124589.0
#
#                                   idat           CT_class  patches
# idat
# 10003886253_R02C02  10003886253_R02C02     Chromothripsis    16213
# 10003886253_R03C01  10003886253_R03C01  No Chromothripsis     6040
# 10003886256_R03C02  10003886256_R03C02  No Chromothripsis    19018
# 10003886258_R02C01  10003886258_R02C01  No Chromothripsis     3811
# 10003886259_R02C01  10003886259_R02C01  No Chromothripsis     7359
# ...                                ...                ...      ...
# 9969477124_R05C02    9969477124_R05C02  No Chromothripsis     3617
# 9980102013_R06C01    9980102013_R06C01  No Chromothripsis    11189
# 9980102032_R03C01    9980102032_R03C01  No Chromothripsis    18452
# 9980102032_R04C01    9980102032_R04C01  No Chromothripsis    22356
# 9980102032_R05C01    9980102032_R05C01  No Chromothripsis     5412
#
# [2215 rows x 20 columns]

# %%
np.random.seed(42)

slide_train, slide_valid = train_test_split(np.array(slide_annots.uuid), train_size = 0.6)

slide_valid, slide_test = train_test_split(slide_valid, train_size = 0.5)

# %%
slide_annots['labels'] = np.abs(1-slide_annots.CT_class.factorize(sort=True)[0])

# %%
np.random.seed(42)


kfold = StratifiedKFold(5)
kfold_test_splits = [x for x in kfold.split(np.array(slide_annots.uuid), np.array(slide_annots.labels))]

# %%
kfold_train_valid_test_splits = [train_test_split(x[0], train_size=0.75, stratify = np.array(slide_annots.labels)[x[0]]) + [x[1]] for x in kfold_test_splits]

# %%
for i in range(5):
    print('starting: '+str(i))
    os.makedirs('/omics/odcf/analysis/OE0585_projects/chromothripsis/histopathology/splits/15052024_UNI/'+str(i),exist_ok=True)
    slide_train = np.array(slide_annots.uuid)[kfold_train_valid_test_splits[i][0]]
    slide_train_files = path_to_extracted_features + slide_train + '.pt'
    patch_num_train = np.array(slide_annots.patches)[kfold_train_valid_test_splits[i][0]]

    slide_valid = np.array(slide_annots.uuid)[kfold_train_valid_test_splits[i][1]]
    slide_valid_files = path_to_extracted_features + slide_valid + '.pt'
    patch_num_valid = np.array(slide_annots.patches)[kfold_train_valid_test_splits[i][1]]

    slide_test = np.array(slide_annots.uuid)[kfold_train_valid_test_splits[i][2]]
    slide_test_files = path_to_extracted_features + slide_test + '.pt'
    patch_num_test = np.array(slide_annots.patches)[kfold_train_valid_test_splits[i][2]]

    
#     patch_num_train = list()

#     for fl in slide_train_files:
#         if(os.path.exists(fl)):
#             patch_num_train.append(torch.load(fl).shape[0])
#         else:
#             patch_num_train.append(0)
    
    train_df = pd.DataFrame({'slide': slide_train,
                             'features': slide_train_files,
                             'patches': patch_num_train})
    train_df.to_csv('/omics/odcf/analysis/OE0585_projects/chromothripsis/histopathology/splits/15052024_UNI/'+str(i)+'/train_set.csv')
    
#     patch_num_valid = list()

#     for fl in slide_valid_files:
#         if(os.path.exists(fl)):
#             patch_num_valid.append(torch.load(fl).shape[0])
#         else:
#             patch_num_valid.append(0)
    
    valid_df = pd.DataFrame({'slide': slide_valid,
                             'features': slide_valid_files,
                             'patches': patch_num_valid})
    valid_df.to_csv('/omics/odcf/analysis/OE0585_projects/chromothripsis/histopathology/splits/15052024_UNI/'+str(i)+'/valid_set.csv')
    
#     patch_num_test = list()

#     for fl in slide_test_files:
#         if(os.path.exists(fl)):
#             patch_num_test.append(torch.load(fl).shape[0])
#         else:
#             patch_num_test.append(0)
    
    test_df = pd.DataFrame({'slide': slide_test,
                             'features': slide_test_files,
                             'patches': patch_num_test})
    test_df.to_csv('/omics/odcf/analysis/OE0585_projects/chromothripsis/histopathology/splits/15052024_UNI/'+str(i)+'/test_set.csv')
# Out:
# starting: 0
# starting: 1
# starting: 2
# starting: 3
# starting: 4

# %%
len(patch_num_train)
# Out:
# 0

# %%
i = 0
slide_train = path_to_extracted_features+np.array(slide_annots.uuid)[kfold_train_valid_test_splits[i][0]] + '.pt'

patch_num_train = list()

for fl in slide_train:
    if(os.path.exists(fl)):
        patch_num_train.append(h5py.File(fl)['feats'].shape[0])
    else:
        patch_num_train.append(0)


train_df = pd.DataFrame({'slide': slide_train,
             'patches': patch_num_train})

# %%
train_df.to_csv('/omics/odcf/analysis/OE0585_projects/chromothripsis/histopathology/splits/02022024/'+str(i)+'/train_set.csv')
# Out:
# ',slide,patches\n0,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/EDA11A46-8944-4488-B491-5A20A937BC92.h5,14822\n1,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/0B86F403-C968-43C8-A6C7-FB22826978AD.h5,6664\n2,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/45992A98-BCD4-4FCF-9A62-3CE2D8E9E680.h5,50\n3,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/EF16DACE-26EA-4D17-9C93-295E8F8550E7.h5,2316\n4,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/1AB9E8D7-FD1D-478D-A2BC-B9728F3452E9.h5,7328\n5,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/EC42213A-E4A7-4668-9CFA-F3C0C12938DD.h5,5055\n6,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/727AC7CA-9C36-4C98-B767-86C088A55653.h5,1721\n7,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/32B5574A-3379-43D1-9878-43E35C1FEACA.h5,2540\n8,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/BC7E390E-A1A5-429C-9FD3-3106E5179368.h5,8582\n9,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/3A2C2EE9-D5ED-4F26-A974-BC89C888F5D6.h5,4262\n10,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/107F2689-9489-476C-B2FE-C320090B17FC.h5,848\n11,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/4378F898-0DD0-4053-BBC2-4FA4FB38AFB3.h5,3411\n12,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/B0FF2612-41D4-4F6B-9D3F-42DE7163EEC1.h5,13\n13,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/AC8D4EA4-B84A-4D48-A858-EBD25D283E5C.h5,0\n14,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/BA8C31F4-BFB3-4033-A9D2-254B7DE54AD8.h5,210\n15,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/BCFFF3F7-5D12-4C85-BC0D-A8ECB8B1DCD4.h5,919\n16,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/75806AB8-DBEF-4C36-B9D4-716B32F8853F.h5,662\n17,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/6E05C79D-3027-4568-97A1-964DADB2BE4A.h5,1632\n18,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/AB3A37B1-C5EB-440D-932A-8846DB052A3D.h5,1318\n19,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/A934B6BB-1FCD-40BA-8BB6-573EA51C4BF9.h5,9760\n20,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/E8662346-65D0-4282-B0FB-8C76FBD7CC8A.h5,1013\n21,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/075376CF-1F9D-4EE2-9988-89A96BA1A018.h5,3264\n22,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/902C256C-22E5-427E-9FAF-CAA206CE46C1.h5,15276\n23,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/156220F5-C6F6-4446-AFC6-290B79B86D86.h5,1743\n24,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/0B4C46F1-E5F2-4DE9-97DD-5BBA735B3773.h5,1493\n25,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/38131288-FE7D-4874-9133-AF96BA067AA4.h5,4847\n26,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/11EE5A40-8F42-4985-B588-6A990EBA70DC.h5,142\n27,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/9EA9528F-4509-4EC0-A6F9-0C16D7AA7DB4.h5,811\n28,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/BFA66A58-E0B8-48FD-90AC-8FE265EF8272.h5,4299\n29,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/348B8962-622A-4E3E-A491-B5707C038B9A.h5,9640\n30,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/47BF8070-43C4-4041-B86C-40E9A289799E.h5,7111\n31,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/D5746BAB-7FF0-4655-8DA2-E7AAA55AFDF0.h5,747\n32,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/550CD836-D9F0-442D-B598-E659E4521906.h5,311\n33,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/87AD2752-777D-44D4-A58D-F65280518C52.h5,3952\n34,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/3B79F122-C264-411F-9264-F37DC6E83E9E.h5,67\n35,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/D36C2148-843A-46D6-A272-262574A76445.h5,6827\n36,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/5F01C194-C8F2-4AAE-A079-73170FE6100C.h5,4817\n37,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/BC2179ED-4E2B-41F3-B2C2-00BB2522A051.h5,7573\n38,/home/p163v/histopathology/UKHD_Neuro/RetCLL_Features/66589969-E642-4F39-A82C-50A04A00D63F. ...

# %%
[x.shape for x in kfold_train_valid_test_splits[0]]
# Out:
# [(1329,), (443,), (443,)]

# %%
patch_num_train = list()


for x in slide_train:
    fl = path_to_extracted_features+x+".h5"
    if(os.path.exists(fl)):
        patch_num_train.append(h5py.File(fl)['feats'].shape[0])
    else:
        patch_num_train.append(0)



patch_num_valid = list()

for x in slide_valid:
    fl = path_to_extracted_features+x+".h5"
    if(os.path.exists(fl)):
        patch_num_valid.append(h5py.File(fl)['feats'].shape[0])
    else:
        patch_num_valid.append(0)


patch_num_test = list()

for x in slide_test:
    fl = path_to_extracted_features+x+".h5"
    if(os.path.exists(fl)):
        patch_num_test.append(h5py.File(fl)['feats'].shape[0])
    else:
        patch_num_test.append(0)

# %%
with open('../metadata/train_set_02022024_01.txt', "w") as f:
    f.write('File,patches\n')
    for i in range(len(slide_train)):
        f.write(slide_train[i]+'.h5,')
        f.write(str(patch_num_train[i]) + '\n')
        

with open('../metadata/valid_set_02022024_01.txt', "w") as f:
    f.write('File,patches\n')
    for i in range(len(slide_valid)):
        f.write(slide_valid[i]+'.h5,')
        f.write(str(patch_num_valid[i]) + '\n')

with open('../metadata/test_set_02022024_01.txt', "w") as f:
    f.write('File,patches\n')
    for i in range(len(slide_test)):
        f.write(slide_test[i]+'.h5,')        
        f.write(str(patch_num_test[i]) + '\n')
